# %% [markdown]
# # Tata Steel AI Hackathon — LightGBM CV
#
# LightGBM with native NaN handling and missingness indicators. For full runs, prefer `train.py` locally; this notebook mirrors the same pipeline.

# %%
# %pip install -q lightgbm scikit-learn pandas numpy joblib matplotlib

# %%
import sys
from pathlib import Path

ROOT = Path('.').resolve().parents[1] if Path('.').name == 'lightgbm-cv' else Path('.').resolve()
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

METHOD_DIR = ROOT / 'models' / 'lightgbm-cv'
DATA_DIR = ROOT / 'dataset'

print('ROOT:', ROOT)
print('METHOD_DIR:', METHOD_DIR)

# %% [markdown]
# ## Train (delegates to train.py logic)
#
# Run the training script for a timestamped run with plots and artifacts:

# %%
# !python "{METHOD_DIR / 'train.py'}" --data-dir "{DATA_DIR}"

# %%
# !python "{METHOD_DIR / 'predict.py'}" --data-dir "{DATA_DIR}"
